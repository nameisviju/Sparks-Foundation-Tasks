# %% [markdown]
# Name: ***Vijay Kate***
#
# ***Data Science and Buisness Analytics Internship***
#
# ***TSF GRIP FEB23***

# %% [markdown]
# Task5: Perform ‘Exploratory Data Analysis’ on dataset ‘Indian Premier League’
#
#
# ●
#  As a sports analysts, find out the most successful teams, players and factors contributing win or loss of a team.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
matches=pd.read_csv('/content/matches.csv')

# %%
dele=pd.read_csv('/content/deliveries.csv')

# %% [markdown]
# Data Cleaning

# %%
matches.shape
# Out:
# (756, 18)

# %%
dele.shape
# Out:
# (103401, 21)

# %%
matches.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches['city'].fillna(matches['city'].mode()[0],inplace=True)

# %%
matches['winner'].fillna(matches['winner'].mode()[0],inplace=True)

# %%
matches['player_of_match'].fillna(matches['player_of_match'].mode()[0],inplace=True)

# %%
matches['umpire1'].fillna(matches['umpire1'].mode()[0],inplace=True)

# %%
matches['umpire2'].fillna(matches['umpire2'].mode()[0],inplace=True)

# %%
matches.isnull().sum()
# Out:
# id                   0
# season               0
# city                 0
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               0
# win_by_runs          0
# win_by_wickets       0
# player_of_match      0
# venue                0
# umpire1              0
# umpire2              0
# umpire3            637
# dtype: int64

# %%
dele.isnull().sum()
# Out:
# match_id                0
# inning                  0
# batting_team            0
# bowling_team            0
# over                    0
# ball                    0
# batsman                 0
# non_striker             0
# bowler                  0
# is_super_over           0
# wide_runs               0
# bye_runs                0
# legbye_runs             0
# noball_runs             0
# penalty_runs            0
# batsman_runs            0
# extra_runs              1
# total_runs              1
# player_dismissed    98262
# dismissal_kind      98262
# fielder             99711
# dtype: int64

# %%
dele["player_dismissed"].fillna('no',inplace=True)

# %%
dele["dismissal_kind"].fillna('no',inplace=True)

# %%
dele.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed         0
# dismissal_kind           0
# fielder             172630
# dtype: int64

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# Exploratory Data Analysis

# %%
matches['winner'].value_counts().plot(kind='barh',color='red')
plt.title('Most winning Team',color='red')
plt.show()

# %%
df=matches[['toss_decision','toss_winner','winner']]

# %%
df[(df['toss_decision']=='field') & (df['toss_winner']==df['winner'])]['winner'].value_counts().plot(kind='bar')
plt.title('Most winning team while chase',color='red')
plt.show()

# %%
df[(df['toss_decision']!='field') & (df['toss_winner']==df['winner'])]['winner'].value_counts().plot(kind='bar')
plt.title('Most winning team while defending',color='red')
plt.show()

# %%
# is toss winnig is match winnig 
matches[matches['toss_winner']==matches['winner']].shape[0]
# Out:
# 393

# %%
matches.shape[0]
# Out:
# 756

# %%
((matches[matches['toss_winner']==matches['winner']].shape[0])/matches.shape[0])*100
# Out:
# 51.98412698412699

# %%
# chance of winnig a match if won a toss is  almost 52%

# %%
# where the most number of matches are played
matches['venue'].value_counts().head(10).plot(kind='barh')
plt.title('Matches in Stdium')
plt.show()

# %%
matches[matches['winner']=='Kolkata Knight Riders']['venue'].value_counts().head()
matches[matches['winner']=='Kolkata Knight Riders']['venue'].value_counts().plot(kind='pie',autopct="%1.1f%%")
plt.title('Kolkata Knight Riders')
plt.show()

# %%
matches[matches['winner']=='Mumbai Indians']['venue'].value_counts().head()
matches[matches['winner']=='Mumbai Indians']['venue'].value_counts().plot(kind='pie',autopct="%1.1f%%")
plt.title('Mumbai Indians')
plt.show()

# %%
matches[matches['winner']=='Royal Challengers Bangalore']['venue'].value_counts().head()
matches[matches['winner']=='Royal Challengers Bangalore']['venue'].value_counts().plot(kind='pie',autopct="%1.1f%%")
plt.title('Royal Challengers Bangalore')
plt.show()

# %%
matches[matches['winner']=='Chennai Super Kings']['venue'].value_counts().head()
matches[matches['winner']=='Chennai Super Kings']['venue'].value_counts().plot(kind='pie',autopct="%1.1f%%")
plt.title('Chennai Super Kings')
plt.show()

# %%
matches[matches['winner']=='Kings XI Punjab']['venue'].value_counts().head()
matches[matches['winner']=='Kings XI Punjab']['venue'].value_counts().plot(kind='pie',autopct="%1.1f%%")
plt.title('Kings XI Punjab')
plt.show()

# %%
matches['toss_winner'].value_counts().plot(kind='barh')
plt.title('most toss winning team')
plt.show()

# %%
matches.pivot_table(index='winner',values='win_by_runs',aggfunc='mean').plot(kind='barh')
plt.title('Team won by avg runs')
plt.show()

# %%
matches.pivot_table(index='winner',values='win_by_wickets',aggfunc='mean').plot(kind='barh')
plt.title('team won by avg number of wickets')
plt.show()

# %%
dele.shape
# Out:
# (103401, 21)

# %%
temp_df = dele.merge(matches,how='outer',left_on='match_id',right_on='id')

# %%
temp_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'season', 'city', 'date', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'result', 'dl_applied',
#        'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue',
#        'umpire1', 'umpire2', 'umpire3'],
#       dtype='object')

# %%
dele.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title('Total Runs')
plt.show()

# %%
tdf=temp_df.groupby(['season','batsman'])['batsman_runs'].sum().sort_values(ascending=False).reset_index()

# %%
bat=tdf.groupby('batsman')
tdf['season']=tdf['season'].astype('object')

# %%
vk=tdf[tdf['batsman']=='V Kohli'][['season','batsman_runs']]

# %%
RG=tdf[tdf['batsman']=='RG Sharma'][['season','batsman_runs']]

# %%
tdf[tdf['batsman']=='RG Sharma']
# Out:
#     season    batsman  batsman_runs
# 38    2013  RG Sharma           538
# 62    2016  RG Sharma           489
# 66    2015  RG Sharma           482
# 103   2012  RG Sharma           433
# 124   2019  RG Sharma           410
# 134   2010  RG Sharma           404
# 135   2008  RG Sharma           404
# 155   2014  RG Sharma           390
# 172   2011  RG Sharma           372
# 186   2009  RG Sharma           362
# 231   2017  RG Sharma           333
# 280   2018  RG Sharma           297

# %%
plt.scatter(x=vk['season'],y=vk['batsman_runs'],marker='D',color='red')
plt.scatter(x=RG['season'],y=RG['batsman_runs'],marker='D')
plt.title('V Kohli and R Sharma')
plt.show()

# %%
# which players hits maximun number of sixes
dele.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
plt.figure(figsize=(8,10))
dele[dele['batsman_runs']==6]['batsman'].value_counts().head(10)
dele[dele['batsman_runs']==6]['batsman'].value_counts().head(10).plot(kind='barh')
plt.title('top 10 six Hitters')
plt.show()

# %%
plt.figure(figsize=(8,10))
dele[dele['batsman_runs']==4]['batsman'].value_counts().head(10)
dele[dele['batsman_runs']==4]['batsman'].value_counts().head(10).plot(kind='barh')
plt.title('top 10 four Hitters')
plt.show()

# %%
plt.figure(figsize=(9,9))
dele[(dele['over']<7) & (dele['batsman_runs']==6)]['batsman'].value_counts().head(10).plot(kind='pie')
plt.title('Top 10 six hitters in powerplay')
plt.show()

# %%
plt.figure(figsize=(9,9))
dele[(dele['over']==20) & (dele['batsman_runs']==6)]['batsman'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%')
plt.title('Players hits sixes in last over')
plt.show()

# %%
plt.figure(figsize=(8,10))
dele[(dele['dismissal_kind']!='run out') & (dele['dismissal_kind']!='retired hurt')]['bowler'].value_counts().head(10).plot(kind='bar')
plt.title( 'Top 10 wicket takers')
plt.show()

# %%
plt.figure(figsize=(9,9))
temp_df[(temp_df['season']>2014)&(temp_df['dismissal_kind']!='run out') & (temp_df['dismissal_kind']!='retired hurt')]['bowler'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%')
plt.title('Top 10 wicket takers from last 5 years')
plt.show()

# %%
plt.figure(figsize=(9,9))
temp_df[(temp_df['season']>2014)&(temp_df['dismissal_kind']!='run out') & (temp_df['dismissal_kind']!='retired hurt')&(temp_df['over']<7)]['bowler'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%')
plt.title('Top 10 wicket takers in powerplay from last 5 years ')
plt.show()

# %%
plt.figure(figsize=(8,10))
temp_df[(temp_df['season']>2014)&(temp_df['dismissal_kind']!='run out') & (temp_df['dismissal_kind']!='retired hurt')&(temp_df['over']==20)]['bowler'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%')
plt.title('Top 10 wicket takers in death overs from last 5 years ')
plt.show()

# %%
plt.figure(figsize=(8,10))
temp_df[(temp_df['season']>2014)&(temp_df['dismissal_kind']!='run out') & (temp_df['dismissal_kind']!='retired hurt')&(temp_df['over']==1)&(temp_df['ball']==1)]['bowler'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%')
plt.title('Top 10 wicket takers in first ball of innings from last 5 years ')
plt.show()

# %%
temp_df.groupby(['season','batsman'])['batsman_runs'].sum().sort_values(ascending=False).reset_index().drop_duplicates('season').sort_values('season')
# Out:
#     season        batsman  batsman_runs
# 14    2008       SE Marsh           616
# 21    2009      ML Hayden           572
# 13    2010   SR Tendulkar           618
# 17    2011       CH Gayle           608
# 3     2012       CH Gayle           733
# 4     2013     MEK Hussey           733
# 10    2014     RV Uthappa           660
# 25    2015      DA Warner           562
# 0     2016        V Kohli           973
# 11    2017      DA Warner           641
# 2     2018  KS Williamson           747
# 5     2019      DA Warner           727

# %%
temp_dff=temp_df[(temp_df['ball']<7)&(temp_df['batsman_runs']==6)]

# %%
grid=temp_dff.pivot_table(index='over',columns='ball',values='batsman_runs',aggfunc='count')

# %%
plt.figure(figsize=(10,20))
plt.imshow(grid)
plt.yticks(np.arange(0,20), list(range(1,21)))
plt.xticks(np.arange(0,6), list(range(1,7)))
plt.colorbar()
plt.title('Sixes in over with ball number')
plt.show()

# %%
temp_df['player_dismissed'].fillna(0,inplace=True)

# %%
temp_df['player_dismissed']
# Out:
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
#             ...
# 179073            0
# 179074            0
# 179075    SR Watson
# 179076            0
# 179077    SN Thakur
# Name: player_dismissed, Length: 179078, dtype: object

# %%
temp_dfff=temp_df[(temp_df['player_dismissed']!=0)&(temp_df['ball']<7)]

# %%
grid1=temp_dfff.pivot_table(index='over',columns='ball',values='player_dismissed',aggfunc='count')

# %%
plt.figure(figsize=(10,20))
plt.imshow(grid1)
plt.yticks(np.arange(0,20), list(range(1,21)))
plt.xticks(np.arange(0,6), list(range(1,7)))
plt.colorbar()
plt.title('wickets in over with ball number')
plt.show()
